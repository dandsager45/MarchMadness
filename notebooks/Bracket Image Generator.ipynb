# %%
#Importing the PIL Libary
from PIL import Image
from PIL import ImageDraw
from PIL import ImageFont

#Open Blank Bracket Image
img = Image.open("/home/daniel/Pictures/blank_bracket.jpg") 

#Call draw method to add 2D graphics
I1 = ImageDraw.Draw(img)


#Header
myFont = ImageFont.truetype("DejaVuSerif-Bold.ttf", 20)
I1.text((20,20), "Title", font=myFont, fill=(0, 0, 0))
myFont = ImageFont.truetype("DejaVuSerif-Bold.ttf", 16)
I1.text((20,40), "MetaData", font=myFont, fill=(0, 0, 0))
I1.text((1100,40), "@DJA", font=myFont, fill=(0, 0, 0))




#Body Text
myFont = ImageFont.truetype("DejaVuSerif-Bold.ttf", 8)


#TODO:

#Import mapping of team names to UUID
#Import team seeding definition
#Import team matchup matrix


#Refine text Adding method


#hacky text printing (Team Names)
C1_Y_values =        [130, 156, 176, 204, 220, 246, 264, 290, \
                      310, 334, 354, 380, 400, 426, 446, 470, \
                      490, 516, 538, 564, 582, 606, 626, 652, \
                      668, 692, 710, 736, 754, 780, 800, 826]

C2_Y_values =        [140, 190, 232, 278, 322, 368, 412, 460, \
                      506, 556, 596, 642, 680, 726, 770, 814]

C3_Y_values =        [164, 254, 342, 434, 528, 618, 700, 790]

C4_Y_values =        [218, 398, 580, 750]

C5_Y_values =        [310, 668]


#first round teams
for x in range(32):
    I1.text((70,C1_Y_values[x]), "text_loc_" + str(x+1), font=myFont, fill=(0, 0, 0))
    I1.text((1042,C1_Y_values[x]), "text_loc_" + str(x+33), font=myFont, fill=(0, 0, 0))

#second round teams
for x in range(16):
    I1.text((140,C2_Y_values[x]), "text_loc_" + str(x+65), font=myFont, fill=(0, 0, 0))
    I1.text((960,C2_Y_values[x]), "text_loc_" + str(x+81), font=myFont, fill=(0, 0, 0))

#third round teams
for x in range(8):
    I1.text((230,C3_Y_values[x]), "text_loc_" + str(x+97), font=myFont, fill=(0, 0, 0))
    I1.text((860,C3_Y_values[x]), "text_loc_" + str(x+105), font=myFont, fill=(0, 0, 0))

#fourth round teams
for x in range(4):
    I1.text((330,C4_Y_values[x]), "text_loc_" + str(x+113), font=myFont, fill=(0, 0, 0))
    I1.text((770,C4_Y_values[x]), "text_loc_" + str(x+117), font=myFont, fill=(0, 0, 0))

#fifth round teams
for x in range(2):
    I1.text((430,C5_Y_values[x]), "text_loc_" + str(x+121), font=myFont, fill=(0, 0, 0))
    I1.text((680,C5_Y_values[x]), "text_loc_" + str(x+123), font=myFont, fill=(0, 0, 0))

#championship teams & winner
I1.text((552,432), "text_loc_125", font=myFont, fill=(0, 0, 0))
I1.text((552,580), "text_loc_126", font=myFont, fill=(0, 0, 0))
I1.text((552,524), "text_loc_127", font=myFont, fill=(0, 0, 0))
            

    
    
###    
#Matchup & Percentage location
myFont = ImageFont.truetype("DejaVuSerif-Bold.ttf", 10)

import random
random.seed(123)

M1_Y_values =        [146, 194, 236, 280, 324, 370, 416, 460, \
                      506, 554, 596, 642, 682, 726, 770, 816]

M2_Y_values =        [170, 258, 348, 440, 536, 622, 706, 794]

M3_Y_values =        [214, 394, 578, 750]

M4_Y_values =        [318, 670]

M5_Y_values =        [498]
                      
#round 1 percentages
for x in range(16):  
    percent1 = random.uniform(0,1)
    pPercent1 = int(percent1 * 100)
    green1 = int(255 * percent1)
    red1 = int(255 - (255* percent1))
    
    percent2 = random.uniform(0,1)
    pPercent2 = int(percent2 * 100)
    green2 = int(255 * percent2)
    red2 = int(255 - (255* percent2))
    
    I1.text((36,M1_Y_values[x]), str(pPercent1) + "%", font=myFont, fill=(red1, green1, 0))
    I1.text((1110,M1_Y_values[x]), str(pPercent2) + "%" , font=myFont, fill=(red2, green2, 0))
    
#round 2 percentages
for x in range(8):
    percent1 = random.uniform(0,1)
    pPercent1 = int(percent1 * 100)
    green1 = int(255 * percent1)
    red1 = int(255 - (255* percent1))
    
    percent2 = random.uniform(0,1)
    pPercent2 = int(percent2 * 100)
    green2 = int(255 * percent2)
    red2 = int(255 - (255* percent2))
    
    I1.text((190,M2_Y_values[x]), str(pPercent1) + "%", font=myFont, fill=(red1, green1, 0))
    I1.text((960,M2_Y_values[x]), str(pPercent2) + "%" , font=myFont, fill=(red2, green2, 0))
    
#round 3 percentages
for x in range(4):
    percent1 = random.uniform(0,1)
    pPercent1 = int(percent1 * 100)
    green1 = int(255 * percent1)
    red1 = int(255 - (255* percent1))
    
    percent2 = random.uniform(0,1)
    pPercent2 = int(percent2 * 100)
    green2 = int(255 * percent2)
    red2 = int(255 - (255* percent2))
    
    I1.text((280,M3_Y_values[x]), str(pPercent1) + "%", font=myFont, fill=(red1, green1, 0))
    I1.text((860,M3_Y_values[x]), str(pPercent2) + "%" , font=myFont, fill=(red2, green2, 0))

#round 4 percentages
for x in range(2):
    percent1 = random.uniform(0,1)
    pPercent1 = int(percent1 * 100)
    green1 = int(255 * percent1)
    red1 = int(255 - (255* percent1))
    
    percent2 = random.uniform(0,1)
    pPercent2 = int(percent2 * 100)
    green2 = int(255 * percent2)
    red2 = int(255 - (255* percent2))
    
    I1.text((380,M4_Y_values[x]), str(pPercent1) + "%", font=myFont, fill=(red1, green1, 0))
    I1.text((770,M4_Y_values[x]), str(pPercent2) + "%" , font=myFont, fill=(red2, green2, 0))


#round 5 percentages
percent1 = random.uniform(0,1)
pPercent1 = int(percent1 * 100)
green1 = int(255 * percent1)
red1 = int(255 - (255* percent1))
 
percent2 = random.uniform(0,1)
pPercent2 = int(percent2 * 100)
green2 = int(255 * percent2)
red2 = int(255 - (255* percent2))
   
I1.text((470,M5_Y_values[0]), str(pPercent1) + "%", font=myFont, fill=(red1, green1, 0))
I1.text((680,M5_Y_values[0]), str(pPercent2) + "%" , font=myFont, fill=(red2, green2, 0))


#Championship percentage

percent1 = random.uniform(0,1)
pPercent1 = int(percent1 * 100)
green1 = int(255 * percent1)
red1 = int(255 - (255* percent1))

I1.text((568,504), str(pPercent1) + "%", font=myFont, fill=(red1, green1, 0))



#Display edited image
img.show()

#Save the Edited Image
img.save("/home/daniel/Pictures/brackets/testBracket.jpg") #Path to saved file
