# %%
#Importing the PIL Libary
from PIL import Image
from PIL import ImageDraw
from PIL import ImageFont

#Open Blank Bracket Image
img = Image.open("/home/daniel/Pictures/blank_bracket.jpg") 

#Call draw method to add 2D graphics
I1 = ImageDraw.Draw(img)


#Header
myFont = ImageFont.truetype("DejaVuSerif-Bold.ttf", 20)
I1.text((20,20), "Title", font=myFont, fill=(0, 0, 0))
myFont = ImageFont.truetype("DejaVuSerif-Bold.ttf", 16)
I1.text((20,40), "MetaData", font=myFont, fill=(0, 0, 0))

#Body Text
myFont = ImageFont.truetype("DejaVuSerif-Bold.ttf", 8)
#Sample method to Add Text 
#I1.text((28,36), "nice Car", font=myFont, fill=(0, 0, 0))

#TODO:

#Import mapping of team names to UUID
#Import team seeding definition
#Import team matchup matrix

#Color Gradient Percentage Maker
#Refine text Adding method
#Determine locations for all text


I1.text((70,130), "text_loc_1", font=myFont, fill=(0, 0, 0))
I1.text((70,156), "text_loc_2", font=myFont, fill=(0, 0, 0))
I1.text((70,176), "text_loc_3", font=myFont, fill=(0, 0, 0))
I1.text((70,204), "text_loc_4", font=myFont, fill=(0, 0, 0))
I1.text((70,220), "text_loc_5", font=myFont, fill=(0, 0, 0))
I1.text((70,246), "text_loc_6", font=myFont, fill=(0, 0, 0))
I1.text((70,264), "text_loc_7", font=myFont, fill=(0, 0, 0))
I1.text((70,290), "text_loc_8", font=myFont, fill=(0, 0, 0))
I1.text((70,310), "text_loc_9", font=myFont, fill=(0, 0, 0))
I1.text((70,334), "text_loc_10", font=myFont, fill=(0, 0, 0))
I1.text((70,354), "text_loc_11", font=myFont, fill=(0, 0, 0))
I1.text((70,380), "text_loc_12", font=myFont, fill=(0, 0, 0))
I1.text((70,400), "text_loc_13", font=myFont, fill=(0, 0, 0))
I1.text((70,426), "text_loc_14", font=myFont, fill=(0, 0, 0))
I1.text((70,446), "text_loc_15", font=myFont, fill=(0, 0, 0))
I1.text((70,470), "text_loc_16", font=myFont, fill=(0, 0, 0))


I1.text((70,490), "text_loc_17", font=myFont, fill=(0, 0, 0))
I1.text((70,580), "text_loc_18", font=myFont, fill=(0, 0, 0))
I1.text((70,600), "text_loc_19", font=myFont, fill=(0, 0, 0))
I1.text((70,627), "text_loc_20", font=myFont, fill=(0, 0, 0))
I1.text((70,647), "text_loc_21", font=myFont, fill=(0, 0, 0))
I1.text((70,694), "text_loc_22", font=myFont, fill=(0, 0, 0))
I1.text((70,721), "text_loc_23", font=myFont, fill=(0, 0, 0))
I1.text((70,741), "text_loc_24", font=myFont, fill=(0, 0, 0))
I1.text((70,768), "text_loc_25", font=myFont, fill=(0, 0, 0))
I1.text((70,788), "text_loc_26", font=myFont, fill=(0, 0, 0))
I1.text((70,815), "text_loc_27", font=myFont, fill=(0, 0, 0))
I1.text((70,835), "text_loc_28", font=myFont, fill=(0, 0, 0))
I1.text((70,862), "text_loc_29", font=myFont, fill=(0, 0, 0))
I1.text((70,882), "text_loc_30", font=myFont, fill=(0, 0, 0))
I1.text((70,909), "text_loc_31", font=myFont, fill=(0, 0, 0))
I1.text((70,929), "text_loc_32", font=myFont, fill=(0, 0, 0))
 

#Display edited image
img.show()

#Save the Edited Image
img.save("/home/daniel/Pictures/brackets/testBracket.jpg") #Path to saved file
